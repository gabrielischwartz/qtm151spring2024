# %% [markdown]
# # <span style="color:darkblue"> Lecture 14 (Optional): Transform </span>
#
# <font size = "5">
#
# This is a complement to Lecture 14

# %% [markdown]
# # <span style="color:darkblue"> I. Import Libraries and Data </span>

# %% [markdown]
# <font size = "5">
# Key libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
results = pd.read_csv("data_raw/results.csv")

# %% [markdown]
# # <span style="color:darkblue"> II. Transform + Groupby </span>

# %% [markdown]
# <font size = "5">
#
# Adding columns with grouped aggregate statistics
#
# <img src="figures/transform_stats.png" alt="drawing" width="300"/>

# %%
# We've use "transform" to compute a column with aggregate statistics
# If we add the pipe "groupby" the aggregate statistics are computed by group
# with group level averages.
# We can use any aggregate function, including "mean", "std", "max","min", etc.

results["mean_points_driver"] = results.groupby("driverId")["points"].transform("mean")
results["std_points_driver"]  = results.groupby("driverId")["points"].transform("std")

# %% [markdown]
# <font size = "5">
#
# Computing the rank

# %%
# The rank function calculates the relative position
# The option 'method = "dense"' options gives multiple individuals
# the same rank if there is a tie
# The option 'ascending = False' indicates the the person with the lowest
# score is "1", the second lowest is "2", etc.

results["rank_points"] = results["points"].rank(method = "dense",
                                                ascending = False)
results
# Out:
#        resultId  raceId  driverId  constructorId number  grid position  \
# 0             1      18         1              1     22     1        1
# 1             2      18         2              2      3     5        2
# 2             3      18         3              3      7     7        3
# 3             4      18         4              4      5    11        4
# 4             5      18         5              1     23     3        5
# ...         ...     ...       ...            ...    ...   ...      ...
# 25835     25841    1096       854            210     47    12       16
# 25836     25842    1096       825            210     20    16       17
# 25837     25843    1096         1            131     44     5       18
# 25838     25844    1096       849              3      6    20       19
# 25839     25845    1096         4            214     14    10       \N
#
#       positionText  positionOrder  points  ...         time milliseconds  \
# 0                1              1    10.0  ...  1:34:50.616      5690616
# 1                2              2     8.0  ...       +5.478      5696094
# 2                3              3     6.0  ...       +8.163      5698779
# 3                4              4     5.0  ...      +17.181      5707797
# 4                5              5     4.0  ...      +18.014      5708630
# ...            ...            ...     ...  ...          ...          ...
# 25835           16             16     0.0  ...           \N           \N
# 25836           17             17     0.0  ...           \N           \N
# 25837           18             18     0.0  ...           \N           \N
# 25838           19             19     0.0  ...           \N           \N
# 25839            R             20     0.0  ...           \N           \N
#
#       fastestLap rank fastestLapTime fastestLapSpeed statusId  \
# 0             39    2       1:27.452         218.300        1
# 1             41    3       1:27.739         217.586        1
# 2             41    5       1:28.090         216.719        1
# 3             58    7       1:28.603         215.464        1
# 4             43    1       1:27.418         218.385        1
# ...          ...  ...            ...             ...      ...
# 25835         39   12       1:29.833         211.632       11
# 25836         40   20       1:31.158         208.556       11
# 25837         42   11       1:29.788         211.738        9
# 25838         45   14       1:30.309         210.517      130
# 25839         24   17       1:30.579         209.889       47
#
#        mean_points_driver  std_points_driver  rank_points
# 0               14.182258           9.224098         16.0
# 1                1.407609           2.372923         20.0
# 2                7.740291           8.672456         25.0
# 3                5.756983           6.330721         26.0
# 4                0.937500           1.969503         29.0
# ...                   ...                ...          ...
# 25835            0.272727           1.335798         39.0
# 25836            1.260563           2.771894         39.0
# 25837           14.182258           9.224098         39.0
# 25838            0.147541           0.813143         39.0
# 25839            5.756983           6.330721         39.0
#
# [25840 rows x 21 columns]

# %%
# The graph shows that the winner gets 50 points
plt.scatter(x = results["rank_points"],y = results["points"])
plt.ylabel("Number of Points")
plt.xlabel("Relative Ranking")
# Out:
# Text(0.5, 0, 'Relative Ranking')

# %% [markdown]
# <font size = "5">
#
# Computing the rank by group

# %%
# The subfunction "transform" allows us to pass-along some of the options

results["rank_points_withinteam"] = (results.groupby("constructorId")["points"]
                                            .transform("rank",
                                                       method = "dense",
                                                       ascending = True))
results
# Out:
#        resultId  raceId  driverId  constructorId number  grid position  \
# 0             1      18         1              1     22     1        1
# 1             2      18         2              2      3     5        2
# 2             3      18         3              3      7     7        3
# 3             4      18         4              4      5    11        4
# 4             5      18         5              1     23     3        5
# ...         ...     ...       ...            ...    ...   ...      ...
# 25835     25841    1096       854            210     47    12       16
# 25836     25842    1096       825            210     20    16       17
# 25837     25843    1096         1            131     44     5       18
# 25838     25844    1096       849              3      6    20       19
# 25839     25845    1096         4            214     14    10       \N
#
#       positionText  positionOrder  points  ...  milliseconds fastestLap rank  \
# 0                1              1    10.0  ...       5690616         39    2
# 1                2              2     8.0  ...       5696094         41    3
# 2                3              3     6.0  ...       5698779         41    5
# 3                4              4     5.0  ...       5707797         58    7
# 4                5              5     4.0  ...       5708630         43    1
# ...            ...            ...     ...  ...           ...        ...  ...
# 25835           16             16     0.0  ...            \N         39   12
# 25836           17             17     0.0  ...            \N         40   20
# 25837           18             18     0.0  ...            \N         42   11
# 25838           19             19     0.0  ...            \N         45   14
# 25839            R             20     0.0  ...            \N         24   17
#
#       fastestLapTime fastestLapSpeed statusId mean_points_driver  \
# 0           1:27.452         218.300        1          14.182258
# 1           1:27.739         217.586        1           1.407609
# 2           1:28.090         216.719        1           7.740291
# 3           1:28.603         215.464        1           5.756983
# 4           1:27.418         218.385        1           0.937500
# ...              ...             ...      ...                ...
# 25835       1:29.833         211.632       11           0.272727
# 25836       1:31.158         208.556       11           1.260563
# 25837       1:29.788         211.738        9          14.182258
# 25838       1:30.309         210.517      130           0.147541
# 25839       1:30.579         209.889       47           5.756983
#
#        std_points_driver  rank_points  rank_points_withinteam
# 0               9.224098         16.0                    13.0
# 1               2.372923         20.0                     8.0
# 2               8.672456         25.0                     9.0
# 3               6.330721         26.0                     6.0
# 4               1.969503         29.0                     6.0
# ...                  ...          ...                     ...
# 25835           1.335798         39.0                     1.0
# 25836           2.771894         39.0                     1.0
# 25837           9.224098         39.0                     1.0
# 25838           0.813143         39.0                     1.0
# 25839           6.330721         39.0                     1.0
#
# [25840 rows x 22 columns]
